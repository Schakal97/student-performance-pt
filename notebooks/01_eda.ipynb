# %% [markdown]
# # 1️⃣ Análise Exploratória dos Dados
#
# ## Objetivo
# Explorar a estrutura e características do dataset de desempenho de alunos.
#
# ---

# %% [markdown]
# ## 📋 Sobre os Dados
#
# - **Fonte**: Dataset de duas escolas secundárias em Portugal
# - **Duas escolas**: GP (Gabriel Pereira) e MS (Mousinho da Silveira)
# - **Total de alunos**: 640 registros
#
# ### Variáveis principais:
# - **Dados pessoais**: age, sex, address, famsize, Pstatus (idade, genêro, tamanho da familia, pais separados ou não)
# - **Educação parental**: Medu, Fedu (nível educacional do pai, nível educacional da mãe)
# - **Status escolar**: traveltime, studytime, failures, schoolsup (tempo de traslado, tempo de estudo, reprovações e suporte escolar)
# - **Notas**: G1, G2, G3 (período 1, 2, 3) e Média geral

# %% [markdown]
# ## 📊 Estatísticas Básicas
#
# ### Distribuição por Escola
# - **GP**: 420 alunos (64.8%)
# - **MS**: 228 alunos (35.2%)
#
# ### Notas (Média Geral)
# - **Mínima**: 0
# - **Máxima**: 20
# - **Média geral**: 11
# - **Mediana**: 12
#
# ### Reprovações (failures)
# - **Sem reprovações**: 86%
# - **Com 1+ falhas**: 14%

# %% [raw]
# ## 🎯 Próximos Passos
#
# No notebook 2, vamos:
# 1. Classificar alunos como ACIMA ou ABAIXO da média
# 2. Calcular taxa de reprovações por grupo
# 3. Verificar se o nível de escolaridade dos pais afeta o desempenho dos filhos
# 4. Analisar hábitos dos alunos e como afetam ou não o desempenho
# 5. Calcular quantos alunos de cada escola tem acesso a internet e a correlação entre o desempenho
# 6. Visualizar os insights
# 7. Propor ações
# 8. Entender grupos críticos
#
# Sempre levando em consideração as duas escolas e os alunos do sexo masculino e feminino
